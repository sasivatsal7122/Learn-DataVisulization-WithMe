# %% [markdown]
# <h1 style="text-align:center">Learn-DataVisulization-WithMe</h1>
#
# <h4 style="text-align:center">Authored By B.Sasi Vatsal</h4>

# %% [markdown]
# ![title](https://ubiq.co/analytics-blog/wp-content/uploads/2020/03/principles-good-data-visualization-design.png)

# %% [markdown]
# ### Welcome to the Part-2 of the Learn-DataVisulization-WithMe series, in this notebook we will be discussing different plotting techniques in Seaborn library through famous Titanic Dataset in a very understandable and easy way, Let's digin

# %% [markdown]
# ![seaborn.png](attachment:seaborn.png)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Looking into datasets offered by SeaBorn Library

# %%
# There are few libraries that are by default shipped with couple of test datasets 
# which can be used for testing 
# lets check what seaborn library offers for us\

sns.get_dataset_names()
# we can a list of datasets available in seaborn, one thing to remember is all these datasets are csv files 
# but not numpy arrays like before. If you came here form my part-1 of DataVisulaization you would we know 
# we already analysed Iris dataset.
# Now we are gonna analyse and visualize One of the most Dataset of all time i.e
# The Titanic Dataset, which consists of details of all the passengers abroad the titanic
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ### Loading the Titanic Dataset

# %%
sns.load_dataset('titanic')
# we can see it is an csv file consisting of 891 rows × 15 columns
# containg feature coloumns such as
#        ['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#       'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#      'alive', 'alone']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df = sns.load_dataset('titanic')

# %% [markdown]
# ### Themeing out garphs

# %%
sns.set_theme(context='notebook',style='darkgrid',palette='deep',font='sans-serif',rc={'figure.figsize':(30,25)})

# %% [markdown]
# # DataVisualization

# %% [markdown]
# ### 1.Hist plots

# %% [markdown]
# Histograms are arguably the most common tool for examining data distributions.
# In a typical histogram, we map a numeric variable to the x axis.
# The x axis is then divided up into a number of “bins” … for example, there might be a bin from 10 to 20, the next bin from 20 to 30, the next from 30 to 40, and so on.
#
# When we create a histogram, we count the number of observations in each binWith Seaborn, histograms are made using the histplot function. You can call the function with default values, what already gives a nice chart. Though, do not forget to play with the number of bins using the ‘bins’ argument. Indeed, a pattern can be hidden under the hood that one would not be able to detect with default bins values.

# %%
# as seaborn is built on the rock solid fondation of matplotlib. u can easily integrate and make use of
# matplotlib functions in seaborn
figure, axes = plt.subplots(2,2,figsize=(12,8))

# making seasborn hist plots for different feature cols in titanic datset
sns.set(font_scale = 1)
sns.histplot(data=titanic_df,x='age',ax=axes[0,0])
sns.histplot(data=titanic_df,x='who',ax=axes[0,1],color='gold')
sns.histplot(data=titanic_df,x='class',ax=axes[1,0],color='green')
sns.histplot(data=titanic_df,x='embark_town',ax=axes[1,1],color='teal')
figure.suptitle("DemoGraphics of the Titanic Passengers")


# by this subplots we can conclude that most of the people travelled in titanic are of age 20yrs,
# most of passengers are men, majority of the passenger belong to the 3rd class and 1st class and finally 
# out of all people travelled in titanic most of them embark form Southampton

# we can observe and analyse a lot from subplots and seaborn library has made it much more simple
# by extracting the data form the feature cols automatically without our itervention
# Out:
# Text(0.5, 0.98, 'DemoGraphics of the Titanic Passengers')

# %%
# setting custom size coz the default size we set earlier seems too small for distplot
sns.set(rc={'figure.figsize':(12,8)})
# making histplot of data titanic df and taking x axis as fare payed by the passengers
# divided by which class they belong to
# the combined what will i get is the fare divison with respect to classe's in terms of actual 
# money payed
sns.histplot(data=titanic_df,x='fare',hue='class',bins=30,multiple='stack')

# we can see that least amount payed is near to 1$ and most of the passenger payed this fare. 
# out of people who payed near to 1% belong mostly to the 3rd class a very few belong to 2nd class
# almost no one belong to 1st class, but as the fare price increases people from 3rd class reduced
# and poeple from 1st and 2nd class increased
# There are 1st class peopel who payed near to $20-$30, they might be children or lucky enough to
# get the 1st class in such cheap rate. In this way try analysing on you're own.
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %% [markdown]
# ### 2. KDE Plot

# %% [markdown]
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization.
#
# The seaborn.kdeplot() function is used to plot the data against a single/univariate variable. It represents the probability distribution of the data values as the area under the plotted curve.

# %%
# making a kde plot using the data titanic df, here i considered x axis to be the age of the passengers
# i divided the graph based on the other parameter i.e class, now the combined graph what i get is 
# frequency or density of which age group of people belong to which type of class
kde_plot = sns.kdeplot(data=titanic_df,x='age',hue='class',shade='true',palette='magma')
kde_plot.set_title("Frequncy distribution of passenger age by class",size=20,y=1.03)

# by this kde density plot we can say that which age group of passengers travelled in which classe's
# most of the passenger in 3rd class belong to the age group of 20yrs
# passengers in both 2nd and 3rd class belong to age group ranging b/w 25-60

# This is magic and beauty of seaborn plots, we can do whatever we wish to do so
# and the complexiy is so less an aesthetically every plot looks marvelous
# Out:
# Text(0.5, 1.03, 'Frequncy distribution of passenger age by class')

# %% [markdown]
# ### 3. ECDF Plot

# %% [markdown]
# We use an empirical cumulative distribution function plot to display the data points in your sample from lowest to highest against their percentiles. These graphs require continuous variables and allow you to derive percentiles and other distribution properties. This function is also known as the empirical CDF or ECDF.
#
# Few Uses of ECDF plotting:
# - Percentiles and proportions for data ranges.
# - Identify where most values occur.
# - Assess the range of your data.
# - Compare sample distributions.
# - Determine how well your data follow a fitted distribution.

# %%
ecdf_plot = sns.ecdfplot(data=titanic_df,x='age',hue='class')
ecdf_plot.set_title("Cumilative age distribution by class",size=20,y=1.03)

# by this ecdf plot we can conclude that 0.8 of the total proportion of passengers belong to the 
# age group of 40yrs likewise we can derive a lot of information form the ecdf plot
# try it on you're own
# Out:
# Text(0.5, 1.03, 'Cumilative age distribution by class')

# %% [markdown]
# ## 4. Dist plot

# %% [markdown]
# A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables.
#
# The Seaborn module along with the Matplotlib module is used to depict the distplot with different variations in it. The Distplot depicts the data by a histogram and a line in combination to it.
#
# Python Seaborn module contains various functions to plot the data and depict the data variations. The seaborn.distplot() function is used to plot the distplot. The distplot represents the univariate distribution of data i.e. data distribution of a variable against the density distribution

# %%
# making dist plot with data titanic_df and col as class and hue as alone
sns.displot(data=titanic_df,x='who',col='class',hue='alone',multiple='stack')

# by this we can say that in all the three classe's man travelled more and also most them travelled alone
# followed by woman we can say that half of the womans in every class almost travelled alone
# only in 3rd class children travlled alone
# we can also say that in 2nd class men travelled alone is less compared to other 2 classe's

# %% [markdown]
# ## 5. Count Plot

# %%
# making count plot to check which deck has the most no.of visitors people idk
sns.countplot(data=titanic_df,x='deck',palette='magma')
# by this we can say that Deck-C is the most popular in the Titanic, find out the reason
# and let me know.
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %%
# Lets us extend our knowledge in countplot by dividing on the basis of class, a minor modification to the 
# above code
# here i just added a hue parameter with class
sns.countplot(data=titanic_df,x='deck',hue='class',palette='magma')

# by this plot we can say that none of the 3 decks A,B,C is shared by other class people
# may be Deck-A,B,C are only reserved for the worthy 
# whereas a very few lucky 2nd class people shared deck with 1st class people on Deck-D
# There are no 1st class passenger in deck-f
# We can also say that Deck-G is only exclusive for 3rd class passengers
# Out:
# <AxesSubplot:xlabel='deck', ylabel='count'>

# %% [markdown]
# ## 6. Point Plots

# %% [markdown]
# A point plot uses scatter plot glyphs to visualize features like point estimates and confidence intervals. A point plot uses scatter plot points to represent the central tendency of numeric data.These plots make use of error bars to indicate any uncertainty around the numeric variables.
# (or) it can be said in simple word as
# it is used to show point estimates and confidence intervals using scatter plot glyphs. A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
# This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.

# %%
# making point plot with x axis as deck and y axis as fare paid
sns.pointplot(data=titanic_df,x='deck',y='fare')

# by this plot we can say that Most of the passengers opted for Deck-B i.e Deck-B
# has the highest fare paid among all the other decks, maybe view from Deck-B would be gr8 idk
# People paid least for deck-g , its obvious from the above plot we can say Deck-G only has 3rd class
# passengers. Even though Deck-A has only 1st class passengers it has relatievely lower price than Deck-D
# what may be the reason? find out... and also conclude other things you observed in the md cell below
# Out:
# <AxesSubplot:xlabel='deck', ylabel='fare'>

# %% [markdown]
# ## Bonus --> Lets see odds of surviving Titanic

# %%
# to know odds of surving let's make a histplot with x axis as class and hue as alive
sns.histplot(data=titanic_df,x='class',hue='alive',multiple='stack',palette='crest')

# by this we can say that if you're from 1st class you have very high probability of surving the Titanic
# unfortunately if you're form 3rd class you're dead for sure, 2nd class has equal probability of survival
# Out:
# <AxesSubplot:xlabel='class', ylabel='Count'>

# %%
# lets dig in more and decompose the plot by class wise and gender wise, let's see which gender has lost 
# more lives in their respective classe's , my guess is men
sns.set(rc={'figure.figsize':(20,18)})
# making distplot of survival chance of respective genders in respective classes
sns.displot(data=titanic_df,x='who',hue='alive',col='class',multiple='stack',palette='viridis')
# by this plot we can say that almost 99% women from 1st class survived the titanic and more that 60% of men
# lost their life in 1st class
# in second class more than 90% lost their life and 95% plus women survived
# death rate of kids in both 1st and 2nd class is almost null
# 3rd class passengers suffered the most deaths, almost every man and women died even
# children died in 3rd class
# if you're gonna ever travel in titanic make sure you afe a women belonging to 1st class
# or not a man belonging to 2nd and 3rd class lol....

# %% [markdown]
# # Thank you , will meet you in the part-2 of seaborn.
#
# ## Until then Peace ✌️.
